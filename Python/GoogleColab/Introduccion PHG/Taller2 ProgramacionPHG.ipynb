# %%
#1.1

s=0
n=int(input("Ingrese el valor de n:"))
for i in range(1,n+1):
  s=s+(1/i)
print("La suma es:",s)

# %%
#1.2

s=0
n=int(input("Ingrese el valor de n:"))
for i in range(1,n+1):
  s=s+(1/i)*((-1)**(i+1))
print("La suma es:",s)

# %%
#1.3

s=0
n=int(input("Ingrese el valor de n:"))
x=float(input("Ingrese el valor de x:"))
for i in range(1,n+1):
  s=s+(x/i)
print("La suma es:",s)

# %%
#1.4

s=0
n=int(input("Ingrese el valor de n:"))
x=float(input("Ingrese el valor de x:"))
for i in range(1,n+1):
  s=s+(x/i)*((-1)**(i+1))
print("La suma es:",s)

# %%
#1.5

n=int(input("Ingrese un valor para n mayor que 0: "))
if n==1:
    s=1
else:
  t1=0
  t2=1
  s=1
  fibo=1
  for i in range(2,n+1):
      fibo=t1+t2
      s=s+fibo
      t1=t2
      t2=fibo
      
print(s)

# %%
#1.6

n=int(input("Ingrese un valor para n mayor que 0: "))
if n==1:
    s=1*-1**i
else:
  t1=0
  t2=1
  s=1*-1**i
  fibo=0
  for i in range(2,n+1):
      fibo=t1+t2
      s=s+fibo*(-1)**i
      t1=t2
      t2=fibo
      
print(s)

# %%
#1.7

s=0
n=int(input("Ingrese el valor de n:"))
for i in range(1,n+1):
  s=s+((i**2)*((2*i)+3))
print("La suma es:",s)

# %%
#1.8

s=0
i=10
for i in range(10,50+1):
  s=s+((i-0.5)*((2*i)-3))
print("La suma es:",s)
# Out:
# La suma es: 80421.5

# %%
#1.9

suma=0
N=int(input("Ingrese el valor de N:"))
x=float(input("Ingrese el valor de x:"))
if N==0:
  print("Error, Division por cero ingrese un numero distinto a 0 para")
  
elif N<0:
  print("Error, Raiz negativa ingrese un numero positivo para N")
else:
  for i in range(1,N+1):
    suma=suma+((x*i)-x)**2
  SN=((1/N)*suma)**0.5
  print("La suma es:",SN)

# %%
3#1.10
import math
ter=int(input("Ingrese el numero de terminos a sumar:"))
n=float(input("Ingrese el valor de n:"))
x=float(input("Ingrese el valor de x:"))
if ter==1:
  s=1
  print("La suma es:",s)
elif ter==2:
  s=(n*x)+1
  print("La suma es:",s)
else:
  ter=ter-2
  fact=1
  acu=0
  for i in range(1,ter+1):
    fact=fact*(i+1)
    s=((n)*(n-i)*(x**(i+1)))/fact
    acu=acu+s
  sn=acu+((n*x)+1)
  print("La suma es:",sn)

# %%
#3

p1=int(input("Ingrese la posición inicial:"))
pf=int(input("Ingrese la posición final:"))
t1=0
t2=1
fibo=1
cont=0
if p1==1:
  print("1")
cont=cont+1
if pf!=1:
  for i in range(1,pf+1):
    fibo=t1+t2
    t1=t2
    t2=fibo
    cont=cont+1
    if cont>=p1:
      if cont<=pf:
        print(fibo)
# Out:
# Ingrese la posición inicial:5
# Ingrese la posición final:10
# 5
# 8
# 13
# 21
# 34
# 55

# %%
#4
import math
ter=int(input("Ingrese el numero de terminos a sumar:"))
n=float(input("Ingrese el valor de n:"))
x=float(input("Ingrese un valor de x:"))
acu=0
for i in range(1,ter+1):
  s=math.factorial(x+i)/(x**(n-(i-1)))
  acu=acu+s
print(acu)
# Out:
# Ingrese el numero de terminos a sumar:5
# Ingrese el valor de n:10
# Ingrese un valor de x:1
# 872.0
