# %%
# !pip install geopandas

# %%
import geopandas

from google.colab import files

uploaded = files.upload()

gdf=geopandas.read_file("/content/Mapa_de_Tierras_de_Colombia.zip")

gdf.describe(include='all')

# %%
import matplotlib.pyplot as plt

# Control del tamaño de la figura del mapa

fig, ejes = plt.subplots(figsize=(15, 15))

# Control del título y los ejes

ejes.set_title('Mapa de Tierras ANH')

ejes.set_xlabel('Longitud')

ejes.set_ylabel('Latitud')

# Mostrar el mapa finalizado

gdf.plot(column='AREA_HA', cmap='plasma', ax=ejes, zorder=5)

# %%
#matriz
mat=[[82,	63,	52,	44,	36,	25,	36],
[91,	42,	85,	72,	64,	19,	73],
[20,	45,	48,	81,	72,	49,	49],
[68,	64,	45,	25,	22,	67,	57],
[62,	17,	45,	54,	63,	92,	78],
[17,	48,	40,	42,	34,	24,	81],
[78,	92,	45,	17,	13,	67,	94],
[15,	56,	11,	53,	49,	51,	84]]
print(mat)

# %%
#imprimir la primera fila
print(mat[1])
# Out:
# [91, 42, 85, 72, 64, 19, 73]

# %%
#imprimir la matriz
for fila in mat:
  print(fila)

# %%
#mostrar estadisticas de la matriz
import pandas as pd
pdf=pd.DataFrame(mat)
pdf.describe()
