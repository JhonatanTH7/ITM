# %%
a=float(input("Digite el valor de a: "))
b=float(input("Digite el valor de b: "))
c=float(input("Digite el valor de c: "))

if a!=0:
  if (b*b)-(4*a*c)==0:
    x=(-b/(2*a))
    print(x)
  else:
    if (b*b)-(4*a*c)>0:
      x1=(-b+(((b*b)-(4*a*c))**0.5))/2*a
      x2=(-b-(((b*b)-(4*a*c))**0.5))/2*a
      print(x1)
      print(x2)
    else:
      x1=-b,"+",((-((b*b)-(4*a*c)))**0.5),"i","/",2*a
      x2=-b,"-",((-((b*b)-(4*a*c)))**0.5),"i","/",2*a
      print("La solución no esta dentro del conjunto de los números reales, a continuación la solución imaginaria (Números complejos): ")
      print(x1)
      print(x2)
else:
  print("ERROR, división por cero, ingrese un valor distinto de cero para a")
