# %%
suma=0
x=float(input("Ingrese x:"))
n=int(input("Ingrese n:"))
for i in range(1,n+1):
  suma=suma+(x-i)**2

print("La suma es: ",suma)

# %%
suma=0
i=1
for i in range(1,10+1):
  suma=suma+((i**2)-i)**2

print("La suma es: ",suma)

# %%
sumai=0
m=int(input("Ingrese m:"))
for i in range(1,10+1):
  sumaj=0
  for j in range(2,m+1):
    sumaj=sumaj+(i**2+1)
  sumai=sumai+sumaj

print("La suma es: ",sumai)

# %%
sumak=0
n=int(input("Ingrese n:"))
m=int(input("Ingrese m:"))
for k in range(1,n+1):
  sumai=0
  for i in range(1,10+1):
    sumaj=0
    for j in range(2,m+1):
      sumaj=sumaj+(i**2+1)
    sumai=sumai+sumaj
  sumak=sumak+sumai

print("La suma es:",sumak)

# %%
suma=0
n=int(input("Ingrese n:"))
for i in range(1,n+1):
  xi=float(input("Ingrese valor de x"+str(i)+":"))
  suma=suma+(xi-i)**2

print("La suma es:",suma)

# %%
s=0
n=int(input("Ingrese n:"))
for i in range(1,n+1):
  s=s+((-1)**(i+1))*i
print("La suma es:",s)

# %%
s=0
n=int(input("Ingrese n:"))
for i in range(1,n+1):
  s=s+((-1)**(i))*i
print("La suma es:",s)
