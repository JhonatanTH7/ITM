# %%
X1=float(input("Ingresar cordenada de X del punto p1 de la recta #1: "))
Y1=float(input("Ingresar cordenada de Y del punto p1 de la recta #1: "))
X2=float(input("Ingresar cordenada de X del punto p2 de la recta #1: "))
Y2=float(input("Ingresar cordenada de Y del punto p2 de la recta #1: "))
X3=float(input("Ingresar cordenada de X del punto p3 de la recta #2: "))
Y3=float(input("Ingresar cordenada de Y del punto p3 de la recta #2: "))
X4=float(input("Ingresar cordenada de X del punto p4 de la recta #2: "))
Y4=float(input("Ingresar cordenada de Y del punto p4 de la recta #2: "))

m1=((Y2-Y1)/(X2-X1))
m2=(Y4-Y3)/(X4-X3)

dp1p2=((X2-X1)**2+(Y2-Y1)**2)**0.5
dp3p4=((X4-X3)**2+(Y4-Y3)**2)**0.5

print("La pendiente de la recta #1 es: ",m1)
print("La distancia entre el punto p1 y p2 es de: ",dp1p2)
print("La pendiente de la recta #2 es: ",m2)
print("La distancia entre el punto p3 y p4 es de: ",dp3p4)
